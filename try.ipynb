# %%
import matplotlib.pyplot as plt

# Extracted EM scores
epochs = list(range(1, 11))  # Assuming 10 epochs
em_scores = [32.79, 35.50, 36.56, 38.71, 38.84, 39.78, 40.61, 40.19, 41.04, 40.43]  # Updated values

# Plot the graph
plt.figure(figsize=(8, 6))
plt.plot(epochs, em_scores, marker='o', linestyle='-', label='Exact Match (EM) Score')

# Formatting to match the reference
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Exact Match Score (%)', fontsize=12)
plt.title('Exact Match Score Over Epochs', fontsize=14)
plt.legend()

# Show the plot
plt.show()
